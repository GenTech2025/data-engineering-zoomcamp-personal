# %%
# Bash Script to download the .zip files

# !mkdir data/
# !cd ./data
# !wget https://fis.fda.gov/content/Exports/faers_ascii_2025Q4.zip
# Out:
# mkdir: data/: File exists
# --2026-04-01 19:32:32--  https://fis.fda.gov/content/Exports/faers_ascii_2025Q4.zip
# Resolving fis.fda.gov (fis.fda.gov)... 150.148.26.113
# Connecting to fis.fda.gov (fis.fda.gov)|150.148.26.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘faers_ascii_2025Q4.zip’
#
# faers_ascii_2025Q4.     [       <=>          ]  64.03M   965KB/s    in 69s
#
# 2026-04-01 19:33:41 (956 KB/s) - ‘faers_ascii_2025Q4.zip’ saved [67144585]

# %%
# !pwd
# Out:
# /home/roy/Desktop/test-projects/data-engineering-zoomcamp-personal/00_Final_Project/testing
